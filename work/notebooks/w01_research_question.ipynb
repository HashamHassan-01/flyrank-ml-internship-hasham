# %% [markdown]
# <a href="https://colab.research.google.com/github/HashamHassan-01/flyrank-ml-internship-hasham/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HashamHassan-01/flyrank-ml-internship-hasham/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !git clone https://github.com/hashamhassan/ml-internship.git
# Out:
# Cloning into 'ml-internship'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !rm -rf flyrank-ml-internship-hasham
# !git clone https://github.com/HashamHassan-01/flyrank-ml-internship-hasham.git
# Out:
# Cloning into 'flyrank-ml-internship-hasham'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 35), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %% [markdown]
# **Lane:** Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it helps identify which content pages should be reviewed first. This is a practical problem since content teams have limited time and resources. Machine learning can analyze performance signals and rank pages that are most likely to benefit from review, helping teams make better decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?
#
# ***Research Question:** Which content pages should be reviewed first for refresh or improvement?
#
# **Decision:** Help the content or SEO team decide which pages should be reviewed first.
#
# **Action:** Review, update, improve, or monitor the highest-ranked pages.
#
# **Cost of a Wrong Recommendation:** If the wrong pages are selected, time and resources are wasted while important pages that actually need attention may continue losing traffic and visibility.
#
# **Why Machine Learning:** Machine learning can analyze many performance signals together and rank pages more effectively than simple fixed rules, making the review process more efficient.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains **30,000 content pages** with **44 features** describing search performance, content characteristics, and engagement metrics. The average CTR is **0.51**, and the average number of sessions over the last 90 days is **37.07**. These observed metrics suggest there is enough information to prioritize which pages may benefit from a content refresh, making this lane suitable for the next seven weeks of analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/flyrank-ml-internship-hasham/data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 2))
print("Average Sessions (90 days):", round(df["sessions_90d"].mean(), 2))
# Out:
# Total pages: 30000
# Average CTR: 0.51
# Average Sessions (90 days): 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').
#
# *This project is intended to provide decision-support by identifying pages that may deserve review based on observed performance data. It can identify patterns and help prioritize content for review, but it cannot prove that refreshing a page will increase traffic or search rankings. It also does not predict Google's ranking algorithm. The recommendations should be treated as evidence-based suggestions that require human judgment before action is taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
